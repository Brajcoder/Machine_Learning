# %%
# #what is scikit learn
# Scikit-learn is an open-source machine learning library for Python. It provides simple and efficient tools for data analysis and modeling, including classification, regression, clustering, dimensionality reduction, and model selection. Scikit-learn is built on top of other popular Python libraries such as NumPy, SciPy, and matplotlib, making it easy to integrate with other data science workflows. It is widely used in both academia and industry for building machine learning models and performing data analysis tasks.

# %% [markdown]
# # Feature Scaling

# %%
#minmax scaling
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)   # Fit the scaler to the training data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 scaler = MinMaxScaler()
# ----> 2 scaler.fit(X_train)   # Fit the scaler to the training data
#
# NameError: name 'X_train' is not defined

# %%
# Custom function for minmax scaling
def minmax_scaling(X):
    x_max = X.max()
    x_min = X.min()
    return (X - x_min) / (x_max - x_min)

# %%
# Mean Scaling
def mean_scaling(X):
    x_mean = X.mean()
    x_max = X.max()
    x_min = X.min()
    return (X - x_mean) / (x_max - x_min)

# %%
# Max abs Scaling
from sklearn.preprocessing import MaxAbsScaler
max_abs_scaler = MaxAbsScaler()
Scaled_train = max_abs_scaler.fit_transform(X_train)
Scaled_test = max_abs_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Max abs Scaling
#       2 from sklearn.preprocessing import MaxAbsScaler
#       3 max_abs_scaler = MaxAbsScaler()
# ----> 4 Scaled_train = max_abs_scaler.fit_transform(X_train)
#       5 Scaled_test = max_abs_scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Robust Scaling
from sklearn.preprocessing import RobustScaler
robust_scaler = RobustScaler()
Scaled_train = robust_scaler.fit_transform(X_train)
Scaled_test= robust_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Robust Scaling
#       2 from sklearn.preprocessing import RobustScaler
#       3 robust_scaler = RobustScaler()
# ----> 4 Scaled_train = robust_scaler.fit_transform(X_train)
#       5 Scaled_test= robust_scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Standard Scaling
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
Scaled_train = standard_scaler.fit_transform(X_train)
Scaled_test = standard_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Standard Scaling
#       2 from sklearn.preprocessing import StandardScaler
#       3 standard_scaler = StandardScaler()
# ----> 4 Scaled_train = standard_scaler.fit_transform(X_train)
#       5 Scaled_test = standard_scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined

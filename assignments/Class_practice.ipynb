# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/my_file (1).csv")

# %%
df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
df.tail()
# Out:
#     Rank Peak All Time Peak     Actual gross Adjusted gross (in 2022 dollars)  \
# 15    16  NaN           NaN     $184,000,000                     $227,452,347
# 16    17  NaN           NaN     $170,000,000                     $213,568,571
# 17    18  NaN           NaN     $169,800,000                     $207,046,755
# 18    19  NaN           NaN  $167,700,000[e]                     $204,486,106
# 19    20  NaN           NaN     $150,000,000                     $185,423,109
#
#           Artist                 Tour title    Year(s)  Shows Average gross  \
# 15          Pink  The Truth About Love Tour  2013–2014    142    $1,295,775
# 16     Lady Gaga         Born This Way Ball  2012–2013     98    $1,734,694
# 17       Madonna           Rebel Heart Tour  2015–2016     82    $2,070,732
# 18         Adele            Adele Live 2016  2016–2017    121    $1,385,950
# 19  Taylor Swift               The Red Tour  2013–2014     86    $1,744,186
#
#     Ref.
# 15  [22]
# 16   [d]
# ...

# %%
df.shape
# Out:
# (20, 11)

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'Peak',
#  'All Time Peak',
#  'Actual\xa0gross',
#  'Adjusted\xa0gross (in 2022 dollars)',
#  'Artist',
#  'Tour title',
#  'Year(s)',
#  'Shows',
#  'Average gross',
#  'Ref.']

# %%
df.dtypes
# Out:
# Rank                                int64
# Peak                                  str
# All Time Peak                         str
# Actual gross                          str
# Adjusted gross (in 2022 dollars)      str
# Artist                                str
# Tour title                            str
# Year(s)                               str
# Shows                               int64
# Average gross                         str
# Ref.                                  str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      str
#  2   All Time Peak                     6 non-null      str
#  3   Actual gross                      20 non-null     str
#  4   Adjusted gross (in 2022 dollars)  20 non-null     str
#  5   Artist                            20 non-null     str
#  6   Tour title                        20 non-null     str
#  7   Year(s)                           20 non-null     str
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     str
#  10  Ref.                              20 non-null     str
# dtypes: int64(2), str(9)
# memory usage: 1.8 KB

# %%
df.describe()
# Out:
#             Rank       Shows
# count  20.000000   20.000000
# mean   10.450000  110.000000
# std     5.942488   66.507617
# min     1.000000   41.000000
# 25%     5.750000   59.000000
# 50%    10.500000   87.000000
# 75%    15.250000  134.500000
# max    20.000000  325.000000

# %%
Numeric = df.select_dtypes(include="number")
Numeric
# Out:
#     Rank  Shows
# 0      1     56
# 1      2     56
# 2      3     85
# 3      4    156
# 4      5     53
# 5      6     88
# 6      7    131
# 7      7     41
# 8      9     49
# 9     10     85
# 10    11    132
# 11    12    203
# 12    13    151
# 13    14    325
# 14    15     60
# 15    16    142
# 16    17     98
# 17    18     82
# 18    19    121
# 19    20     86

# %%
Categorical = df.select_dtypes(include="object")
Categorical
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23500\3616488947.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   Categorical = df.select_dtypes(include="object")
#      Peak All Time Peak     Actual gross Adjusted gross (in 2022 dollars)  \
# 0       1             2     $780,000,000                     $780,000,000
# 1       1          7[2]     $579,800,000                     $579,800,000
# 2    1[4]          2[5]     $411,000,000                     $560,622,615
# 3    2[7]         10[7]     $397,300,000                     $454,751,555
# ...

# %%
df.isnull().sum()
# Out:
# Rank                                 0
# Peak                                11
# All Time Peak                       14
# Actual gross                         0
# Adjusted gross (in 2022 dollars)     0
# Artist                               0
# Tour title                           0
# Year(s)                              0
# Shows                                0
# Average gross                        0
# Ref.                                 0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                                19
# Peak                                 7
# All Time Peak                        6
# Actual gross                        20
# Adjusted gross (in 2022 dollars)    20
# Artist                               9
# Tour title                          20
# Year(s)                             16
# Shows                               18
# Average gross                       20
# Ref.                                20
# dtype: int64

# %%
Numeric
# Out:
#     Rank  Shows
# 0      1     56
# 1      2     56
# 2      3     85
# 3      4    156
# 4      5     53
# 5      6     88
# 6      7    131
# 7      7     41
# 8      9     49
# 9     10     85
# 10    11    132
# 11    12    203
# 12    13    151
# 13    14    325
# 14    15     60
# 15    16    142
# 16    17     98
# 17    18     82
# 18    19    121
# 19    20     86

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'Peak',
#  'All Time Peak',
#  'Actual\xa0gross',
#  'Adjusted\xa0gross (in 2022 dollars)',
#  'Artist',
#  'Tour title',
#  'Year(s)',
#  'Shows',
#  'Average gross',
#  'Ref.']

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.isnull().sum()
# Out:
# Rank                                0
# Peak                                0
# All Time Peak                       0
# Actual gross                        0
# Adjusted gross (in 2022 dollars)    0
# Artist                              0
# Tour title                          0
# Year(s)                             0
# Shows                               0
# Average gross                       0
# Ref.                                0
# dtype: int64

# %%
df_cleaned = df.drop_duplicates()

# %%
df_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      str
#  2   All Time Peak                     6 non-null      str
#  3   Actual gross                      20 non-null     str
#  4   Adjusted gross (in 2022 dollars)  20 non-null     str
#  5   Artist                            20 non-null     str
#  6   Tour title                        20 non-null     str
#  7   Year(s)                           20 non-null     str
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     str
#  10  Ref.                              20 non-null     str
# dtypes: int64(2), str(9)
# memory usage: 1.8 KB

# %%
df_cleaned
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
# Find Outliers in the numeric 
Q1 = Numeric.quantile(0.25)
Q3 = Numeric.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# diff b/w nunique and unique
# nunique() returns the number of unique values in a column, while unique() returns an array of the unique values themselves.
